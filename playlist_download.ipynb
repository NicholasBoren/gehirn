# %%
import pytube
from pytube.exceptions import PytubeError
import http.client
from googleapiclient.discovery import build
import pandas as pd
import sys
from constants import YOUTUBE_API_KEY
from data_mining import data_mining_source
import os
from random import sample
import moviepy
import pretty_midi
import numpy as np
import copy
# Out:
# /Users/huongngo/opt/anaconda3/envs/gehirn/lib/python3.11/site-packages/fastprogress/fastprogress.py:107: UserWarning: Couldn't import ipywidgets properly, progress bar will use console behavior
#   warn("Couldn't import ipywidgets properly, progress bar will use console behavior")

# %%
def robust_download(video_url: str) -> List[Union[str, int]]:
    """Downloads the mp4 video file from the input YouTube video URL, converts it to an mp3 audio file and returns
       the video metadata.

    Args:
        video_url: The URL of the YouTube video to download.

    Returns:
        A tuple of two items:
            - A dictionary containing video metadata, including video ID, file path, length, rating, description, and keywords.
            - A list containing video channel ID, video ID, description, length, publish date, and file path.
    """
    try:
        video = pytube.YouTube(video_url)
        video_name = video.title.replace('/', '') + '.mp4'
        audio_name = video.title.replace('/', '') + '.mp3'
        output_path = os.path.join('dataset', GENRE_TAG, video.title)

        if not os.path.isdir(output_path) and not video.length > 360:
            os.makedirs(output_path)

        if not os.path.isfile(os.path.join(output_path, audio_name)) and not video.length > 360:
            video.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').asc() \
                 .first().download(filename=video_name, output_path=output_path)

            video_editor = moviepy.editor.VideoFileClip(os.path.join(output_path, video_name))
            video_editor.audio.write_audiofile(os.path.join(output_path, audio_name), logger=None)
            os.remove(os.path.join(output_path, video_name))

        row = []
        if not video.length > 360:
            row = [video.video_id, video.channel_id,
                   video.title, video.description,
                   video.length, video.publish_date,
                   video.rating, video.keywords,
                   os.path.join(output_path, audio_name)
            ]

        return row

    except (PytubeError, http.client.IncompleteRead) as e:
        print('Error: ', e)
        print(video_url)
        return []

# %%
def song_playlists(playlist_id: str) -> pd.DataFrame:
    
    data = []
    url = f'https://www.youtube.com/playlist?list={playlist_id}'
    playlist = pytube.Playlist(url)
    video_urls = playlist.video_urls
    for video_url in video_urls:
        row = robust_download(video_url)
        row.insert(2, playlist_id)
        data.append(row)

    videos_table = pd.DataFrame(data, columns=[
        'VideoID', 'ChannelID', 'PlaylistID',
        'videoTitle', 'descriptions', 'length', 'publishedDate',
        'videoRating', 'videoKeyWords', 'pathToRaw']
    )
    output_path = os.path.join('dataset', GENRE_TAG, f'{playlist_id}_META_DATA.csv')
    videos_table.to_csv(output_path)
    return videos_table

# %%
# example use (insert playlist id, can be found at the end of the playlist link)
GENRE_TAG = 'electronic'
playlists = ['PLEb0_nNrLidAcRNKYubWmueQKGbhp9cUf', 'PLh5yQEh2F60v3bjv5M1PlD-DO9V1D7GkI']
for playlist_id in playlists:
    song_playlists(playlist_id)
# Out:
# Error:  Exception while accessing title of https://youtube.com/watch?v=GDnU6nbL1uQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=GDnU6nbL1uQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=GaYzv2cvGNc. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=GaYzv2cvGNc
# Error:  Exception while accessing title of https://youtube.com/watch?v=w6x6TdOI_GE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=w6x6TdOI_GE
# Error:  Exception while accessing title of https://youtube.com/watch?v=sLyrooXOGkU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=sLyrooXOGkU
# Error:  Exception while accessing title of https://youtube.com/watch?v=cOfa6poaRU8. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=cOfa6poaRU8
# Error:  Exception while accessing title of https://youtube.com/watch?v=JsjF7wgdb0s. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=JsjF7wgdb0s
# Error:  Exception while accessing title of https://youtube.com/watch?v=Tsq5ZPu_ndM. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Tsq5ZPu_ndM
# Error:  Exception while accessing title of https://youtube.com/watch?v=xP5KGsMC7Xc. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=xP5KGsMC7Xc
# Error:  Exception while accessing title of https://youtube.com/watch?v=EiCq8ynfOi4. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=EiCq8ynfOi4
# Error:  Exception while accessing title of https://youtube.com/watch?v=2nqvxJMnWS4. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=2nqvxJMnWS4
# Error:  Exception while accessing title of https://youtube.com/watch?v=1emNBL1q7Bo. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=1emNBL1q7Bo
# Error:  Exception while accessing title of https://youtube.com/watch?v=3paS2rtVpGU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=3paS2rtVpGU
# Error:  Exception while accessing title of https://youtube.com/watch?v=ZglQRphE96U. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=ZglQRphE96U
# Error:  Exception while accessing title of https://youtube.com/watch?v=2cTMw4U6Edw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=2cTMw4U6Edw
# Error:  Exception while accessing title of https://youtube.com/watch?v=bLgWIDF9N0A. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=bLgWIDF9N0A
# Error:  Exception while accessing title of https://youtube.com/watch?v=ghZTgDp9ntk. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=ghZTgDp9ntk
# Error:  Exception while accessing title of https://youtube.com/watch?v=thKT8mki-EU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=thKT8mki-EU
# Error:  Exception while accessing title of https://youtube.com/watch?v=kB2U1LJBcV8. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=kB2U1LJBcV8
# Error:  Exception while accessing title of https://youtube.com/watch?v=aMzYXbSuH50. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=aMzYXbSuH50
# Error:  Exception while accessing title of https://youtube.com/watch?v=abpN9e7s37A. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=abpN9e7s37A
# Error:  Exception while accessing title of https://youtube.com/watch?v=ngi7umk57Ts. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=ngi7umk57Ts
# Error:  Exception while accessing title of https://youtube.com/watch?v=KaQCogT___A. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=KaQCogT___A
# Error:  Exception while accessing title of https://youtube.com/watch?v=7eEs9TOe-YE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=7eEs9TOe-YE
# Error:  Exception while accessing title of https://youtube.com/watch?v=OhAUW0Hg-50. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=OhAUW0Hg-50
# Error:  Exception while accessing title of https://youtube.com/watch?v=QRceUhuEQz8. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=QRceUhuEQz8
# Error:  Exception while accessing title of https://youtube.com/watch?v=rBJUpUCfPVU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=rBJUpUCfPVU
# Error:  Exception while accessing title of https://youtube.com/watch?v=-BG9LWtlfEw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=-BG9LWtlfEw
# Error:  Exception while accessing title of https://youtube.com/watch?v=6fZdhVT7954. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=6fZdhVT7954
# Error:  Exception while accessing title of https://youtube.com/watch?v=gs9UC1qtHu0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=gs9UC1qtHu0
# Error:  Exception while accessing title of https://youtube.com/watch?v=8TDkGeZs9TE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=8TDkGeZs9TE
# Error:  Exception while accessing title of https://youtube.com/watch?v=yg_V6LzDdSQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=yg_V6LzDdSQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=bMDMlX0DugY. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=bMDMlX0DugY
# Error:  Exception while accessing title of https://youtube.com/watch?v=HQozceVazhI. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=HQozceVazhI
# Error:  Exception while accessing title of https://youtube.com/watch?v=p8cSmJz8BXQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=p8cSmJz8BXQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=n6yMZJxZb5M. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=n6yMZJxZb5M
# Error:  Exception while accessing title of https://youtube.com/watch?v=PO_K82gBCl0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=PO_K82gBCl0
# Error:  Exception while accessing title of https://youtube.com/watch?v=xauo_Iy6zEw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=xauo_Iy6zEw
# Error:  Exception while accessing title of https://youtube.com/watch?v=v572eUdPz1c. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=v572eUdPz1c
# Error:  Exception while accessing title of https://youtube.com/watch?v=ftcqtyflluU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=ftcqtyflluU
# Error:  Exception while accessing title of https://youtube.com/watch?v=wjjpoW_NjOQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=wjjpoW_NjOQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=Fe59rKjBrv0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Fe59rKjBrv0
# Error:  Exception while accessing title of https://youtube.com/watch?v=Lj84tQwSsf8. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Lj84tQwSsf8
# Error:  Exception while accessing title of https://youtube.com/watch?v=1eeROH_83Ak. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=1eeROH_83Ak
# Error:  Exception while accessing title of https://youtube.com/watch?v=uo6sNbFyjgo. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=uo6sNbFyjgo
# Error:  Exception while accessing title of https://youtube.com/watch?v=cnjz1t_OpXw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=cnjz1t_OpXw
# Error:  Exception while accessing title of https://youtube.com/watch?v=nTRBWh8Vp_Y. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=nTRBWh8Vp_Y
# Error:  Exception while accessing title of https://youtube.com/watch?v=FoyJCHOrDZE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=FoyJCHOrDZE
# Error:  Exception while accessing title of https://youtube.com/watch?v=dZ-yGi0H_ZQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=dZ-yGi0H_ZQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=iTEgNS0T9C8. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=iTEgNS0T9C8
# Error:  Exception while accessing title of https://youtube.com/watch?v=Sj8u56d_L-0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Sj8u56d_L-0

# %%
GENRE_TAG = 'movie'
playlists = ['PLzZfeWyGFlb-dre7blTNpEu4kG_PdGddw', 'PLh5yQEh2F60uqmOl9oRWD6SyEarU2kqo2']
for playlist_id in playlists:
    song_playlists(playlist_id)
# Out:
# Error:  Exception while accessing title of https://youtube.com/watch?v=9Tao0pjhWlY. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=9Tao0pjhWlY
# Error:  Exception while accessing title of https://youtube.com/watch?v=PjftUHqOueI. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=PjftUHqOueI
# Error:  Exception while accessing title of https://youtube.com/watch?v=84JJDtesQdE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=84JJDtesQdE
# Error:  Exception while accessing title of https://youtube.com/watch?v=girEeLHsGEE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=girEeLHsGEE
# Error:  Exception while accessing title of https://youtube.com/watch?v=2StnCCog7IY. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=2StnCCog7IY
# Error:  Exception while accessing title of https://youtube.com/watch?v=P1-LfQKZ5Bk. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=P1-LfQKZ5Bk
# Error:  Exception while accessing title of https://youtube.com/watch?v=-qMpTH9qKLw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=-qMpTH9qKLw
# Error:  Exception while accessing title of https://youtube.com/watch?v=svaC9p6qLbk. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=svaC9p6qLbk
# Error:  Exception while accessing title of https://youtube.com/watch?v=aA28W0N8Hb0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=aA28W0N8Hb0
# Error:  Exception while accessing title of https://youtube.com/watch?v=Ued1SuUti6I. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Ued1SuUti6I
# Error:  Exception while accessing title of https://youtube.com/watch?v=PhQM6RB7dtM. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=PhQM6RB7dtM
# Error:  Exception while accessing title of https://youtube.com/watch?v=zWDeYlbrk_k. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=zWDeYlbrk_k
# Error:  Exception while accessing title of https://youtube.com/watch?v=N23HHa0LJ5U. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=N23HHa0LJ5U
# Error:  Exception while accessing title of https://youtube.com/watch?v=7pK2gd9edFQ. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=7pK2gd9edFQ
# Error:  Exception while accessing title of https://youtube.com/watch?v=JgwImKwjlP4. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=JgwImKwjlP4
# Error:  Exception while accessing title of https://youtube.com/watch?v=aGdmdeUabtk. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=aGdmdeUabtk
# Error:  Exception while accessing title of https://youtube.com/watch?v=Po2xOfz_Cpw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=Po2xOfz_Cpw
# Error:  Exception while accessing title of https://youtube.com/watch?v=EEY0FsLDxPU. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=EEY0FsLDxPU
# Error:  Exception while accessing title of https://youtube.com/watch?v=vjf8iOpEn18. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=vjf8iOpEn18
# Error:  Exception while accessing title of https://youtube.com/watch?v=lAK0IHbasnM. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=lAK0IHbasnM
# Error:  Exception while accessing title of https://youtube.com/watch?v=PNbFSAH2nJ4. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=PNbFSAH2nJ4
# Error:  Exception while accessing title of https://youtube.com/watch?v=HQZbeC2sf7E. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=HQZbeC2sf7E
# Error:  Exception while accessing title of https://youtube.com/watch?v=ikTAmoEMWcs. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=ikTAmoEMWcs
# Error:  Exception while accessing title of https://youtube.com/watch?v=5FveSzkCQQc. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=5FveSzkCQQc
# Error:  Exception while accessing title of https://youtube.com/watch?v=RrJDZ2xStt0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=RrJDZ2xStt0
# Error:  Exception while accessing title of https://youtube.com/watch?v=l_ZOyCzcsbE. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=l_ZOyCzcsbE
# Error:  Exception while accessing title of https://youtube.com/watch?v=_riKsapJw9E. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=_riKsapJw9E
# Error:  Exception while accessing title of https://youtube.com/watch?v=tkFq0OGN5eY. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=tkFq0OGN5eY
# Error:  Exception while accessing title of https://youtube.com/watch?v=gRQlb3emSIA. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=gRQlb3emSIA
# Error:  Exception while accessing title of https://youtube.com/watch?v=vCja-NiX59Q. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=vCja-NiX59Q
# Error:  Exception while accessing title of https://youtube.com/watch?v=1Covpr48yDw. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=1Covpr48yDw
# Error:  Exception while accessing title of https://youtube.com/watch?v=MTG1Nt-un_0. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=MTG1Nt-un_0
# Error:  Exception while accessing title of https://youtube.com/watch?v=vCvYgG9wYvM. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=vCvYgG9wYvM
# Error:  Exception while accessing title of https://youtube.com/watch?v=tyVWN2BQXdo. Please file a bug report at https://github.com/pytube/pytube
# https://www.youtube.com/watch?v=tyVWN2BQXdo
